# %%
import os
import cv2 as cv
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
from scipy.signal import convolve, convolve2d, correlate2d

# %%
plt.rcParams["font.size"] = 20
plt.rcParams["figure.figsize"] = (20, 10)

# %% [markdown]
# # directory structure:
# - source
#     - Lab1.ipynb
# - data
#     - messi.jpg
#     - zebra.jpg

# %%
data_dir = '../data/' #relative path from notebook
img_messi_bgr = cv.imread(data_dir + 'messi.jpg')
img_messi_rgb = cv.cvtColor(img_messi_bgr, cv2.COLOR_BGR2RGB)
fig, ax = plt.subplots()
ax.set_axis_off()
ax.imshow(img_messi_rgb)
plt.show()

# %%
img_messi_bgr = cv.rectangle()
